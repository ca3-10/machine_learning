# %%
import matplotlib.pyplot as plt

# %%
t_values = [-0.4, 1.6, 3.6, 5.6, 7.6, 9.6, 11.6, 13.6, 15.6, 17.6]
a_vaules = [-0.45, 0.65, 3.95, 13.85, 43.55, 132.65, 399.95, 1201.85, 3607.55, 10824.65]
b_values = [-0.05, -1.05, -1.85, 2.35, 34.75, 191.35, 839.35, 3317.95, 12357.55, 44287.75]
c_values = [0, -2.6, 2.8, 17, 60, 244.6, 1067.6, 4494.6, 17848, 17848]
plt.plot(t_values, a_vaules)
plt.plot(t_values, b_values)
plt.plot(t_values, c_values)
plt.show()
